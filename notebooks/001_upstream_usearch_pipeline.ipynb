# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [USEARCH pipeline](#toc1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # 1. <a id='toc1_'></a>[USEARCH pipeline](#toc0_)

# %% [markdown]
# <div style="display:flex;justify-content:center">
#
# ```mermaid
# ---
# title: USEARCH pipeline
# ---
# flowchart TD;
#     A([raw reads])--"-fastq_mergepairs @"-->B[merged reads] --"-fastq_filter"--> C[filtered reads];
#     C[filtered reads] --"-fastx_uniques"--> D[dereplicated reads];
#     D --"-cluster_otus"--> OTU[OTU];
#     D --"-unoise3"--> ZOTU[ZOTU];
#     OTU --> fasta([reference sequences]);
#     ZOTU --> fasta;
#     fasta -. "-otutab/zotutab" .-> feature_table[OTU/ZOTU table];
#     B -.-> feature_table;
#     feature_table --"-otutab_rare"--> normalized([normalized table]);
#     fasta --"-sintax"--> taxa[taxanomy];
# ```
#
# </div>

# %%
from microbiome import usearch_pipeline


help(usearch_pipeline.UsearchPipeline)
# Out:
# Help on class UsearchPipeline in module microbiome.usearch_pipeline:
#
# class UsearchPipeline(builtins.object)
#  |  UsearchPipeline(home_dir: str, threads: int | None = None, db_file: str | None = None, usearch_version: str = 'usearch12')
#  |
#  |  Usearch pipeline for 16S rRNA amplicon data analysis.
#  |  USEARCH11 (https://www.drive5.com/usearch/manual/),
#  |  USEARCH12 (https://rcedgar.github.io/usearch12_documentation/cmds.html),
#  |  Including quality control, merging paired-end reads, filtering low-quality reads, dereplication, removing singletons,
#  |  preorder, clustering to OTUs, denoising to zOTUs, building OTU and zOTU feature tables.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, home_dir: str, threads: int | None = None, db_file: str | None = None, usearch_version: str = 'usearch12')
#  |      Initialize the pipeline with home directory and number of threads.
#  |      Args:
# ...

# %%
def run_usearch_pipeline(home_dir: str) -> None:
    usearch = usearch_pipeline.UsearchPipeline(home_dir=home_dir, usearch_version='usearch12', db_file='/bmp/backup/zhaosy/ws/china_16s_pipeline/dbs/rdp_16s_v18_usearch.udb')
    usearch.run(connect='.', fastq_format='fq')

    return None 


# Run
run_usearch_pipeline(home_dir='/bmp/backup/zhaosy/ws/china_16s_pipeline/results_demo')
# Out:
# 2026-05-27 11:34:37.195 | INFO     | microbiome.usearch_pipeline:__init__:53 - Home directory set to /bmp/backup/zhaosy/ws/china_16s_pipeline/results_demo
# 2026-05-27 11:34:37.195 | INFO     | microbiome.usearch_pipeline:run:293 - Running the Usearch pipeline with usearch12 ...
# 2026-05-27 11:34:37.196 | INFO     | microbiome.usearch_pipeline:show_files:75 - Data directory is set to: /bmp/backup/zhaosy/ws/china_16s_pipeline/results_demo/datas
# 2026-05-27 11:34:37.196 | INFO     | microbiome.usearch_pipeline:quality_control:81 - Quality control step starting...
# 2026-05-27 11:34:37.197 | INFO     | microbiome.usearch_pipeline:merge_paired_end_reads:102 - Merging paired-end reads...
# [Parallel(n_jobs=64)]: Using backend LokyBackend with 64 concurrent workers.
# [Parallel(n_jobs=64)]: Done 1 out of 6 | elapsed:    4.0s
# [Parallel(n_jobs=64)]: Done 2 out of 6 | elapsed:    4.0s remaining:    8.1s
# [Parallel(n_jobs=64)]: Done 3 out of 6 | elapsed:    4.1s remaining:    4.1s
# ...
