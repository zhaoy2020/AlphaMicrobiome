# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Import package](#toc1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # 1. <a id='toc1_'></a>[Import package](#toc0_)

# %%
from microbiome import amplicon, diversity, stats


help(amplicon)

# %% [markdown]
# # NCBI

# %%
from microbiome import ncbi 


help(ncbi.SRATools.download)

# %% [markdown]
# ```bash
# ncbi.SRATools.download(
#     self,
#     srr_ids: list,
#     sequence_types: list[typing.Literal['single', 'paired']],
#     output_dir: str = '.',
#     method: str = 'asp',
#     backend: Literal['loky', 'multiprocessing', 'threading'] = 'threading',
#     pre_dispath: int = 5,
#     verbose: int = 10,
# )
# Docstring:
# Download SRA data using specified method.
# Args:
#     srr_ids: List of SRA IDs to download.
#     sequence_types: List of sequence types to download. Options are 'paired' and 'single'.
#     method: Method to use for downloading. Options are 'asp' and 'fasp'.
#     output_dir: Directory to save downloaded files.
# Returns:
#     None
#
# Examples:
# >>> srr_ids = ['SRR12345678', 'SRR12345679']
# >>> sequence_types = ['paired', 'single']
# >>> output_dir = './data'
# >>> sratoools = SRATools()
# >>> sratoools.download(srr_ids, sequence_types, output_dir, method='asp', backend='threading', pre_dispath=5, verbose=10)
# ```
